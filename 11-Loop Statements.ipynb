# %% [markdown]
# # Loop Statements

# %% [markdown]
# - Loop statements allow you to repeatedly execute a block of code until a certain condition is met.
# - This is useful for tasks that involve iteration, such as processing lists, performing calculations, or generating patterns.

# %% [markdown]
# ## Python Loops

# %% [markdown]
# Python has two primitive loop commands:
#
# - while loops
# - for loops

# %% [markdown]
# ## Python while Loop

# %% [markdown]
# - Python `while` loop is used to run a block code until a certain condition is met.
# - With the while loop we can execute a set of statements as long as a condition is true.

# %% [markdown]
# #### Syntax of while Loop

# %%
while condition:
    # Code to execute as long as the condition is true

# %% [markdown]
# Here,
#
# -->  A while loop evaluates the condition
#
# -->  If the condition evaluates to True, the code inside the while loop is executed.
#
# -->  Condition is evaluated again.
#
# -->  This process continues until the condition is False.
#
# -->  When condition evaluates to False, the loop stops.

# %% [markdown]
# ![image.png](attachment:01eae0e6-9986-415e-b688-ad799505b8ec.png)

# %%
# initialize the variable
i = 0

while i <= 5:
    print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
text = "Hello Deva"
index = 0

while index < len(text):
    print(text[index])
    index += 1
# Out:
# H
# e
# l
# l
# o
#
# D
# e
# v
# a

# %%
word = "Devaraju"
num = 0

i = 0
while i < len(word):
    print(word)
    num += 1
    i += 1
# Out:
# Devaraju
# Devaraju
# Devaraju
# Devaraju
# Devaraju
# Devaraju
# Devaraju
# Devaraju

# %%
string = "Hello, world!"
vowels = "aeiouAEIOU"
count = 0
i = 0

while i < len(string):
    if string[i] in vowels:
        count += 1
    i += 1

print("Number of vowels:", count)
# Out:
# Number of vowels: 3

# %% [markdown]
# ## Python For Loops

# %% [markdown]
# - A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).
# -  And execute a block of code repeatedly for each item in the sequence.
# -  The for loop is versatile and widely used for various types of iteration.

# %% [markdown]
# #### Syntax of For Loop

# %%
for variable in sequence:
    # Code to execute for each item in the sequence

# %% [markdown]
# Here, val accesses each item of the sequence on each iteration.
#
# The loop continues until we reach the last item in the sequence.

# %% [markdown]
# ![image.png](attachment:b74b0327-242a-4675-a86e-a8fe00991ee1.png)

# %%
language = 'Python'

# iterate over each character in language
for x in language:
    print(x)
# Out:
# P
# y
# t
# h
# o
# n

# %%
fruits = ['apple', 'banana', 'orange']

for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# orange

# %%
Roll_numbers = {'Deva': 571, 'Sakku': 583, 'Ajay Kumar': 552, 'Gopal': 599}

for name, number in Roll_numbers.items():
    print(f"{name}'s roll number is {number}")
# Out:
# Deva's roll number is 571
# Sakku's roll number is 583
# Ajay Kumar's roll number is 552
# Gopal's roll number is 599

# %%
names = ["Deva", "Sakku", "Ajay"]
ages = [20, 21, 21]
for name, age in zip(names, ages):
    print(name , age)
# Out:
# Deva 20
# Sakku 21
# Ajay 21
